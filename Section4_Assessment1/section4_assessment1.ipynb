# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#SQL-Introduction" data-toc-modified-id="SQL-Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>SQL Introduction</a></span></li><li><span><a href="#Connect-to-the-SQL" data-toc-modified-id="Connect-to-the-SQL-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Connect to the SQL</a></span></li><li><span><a href="#Know-your-database" data-toc-modified-id="Know-your-database-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Know your database</a></span></li><li><span><a href="#Create-pandas-dataframes" data-toc-modified-id="Create-pandas-dataframes-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Create pandas dataframes</a></span></li><li><span><a href="#Make-dataframes-columns-dtype-good" data-toc-modified-id="Make-dataframes-columns-dtype-good-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Make dataframes columns dtype good</a></span></li><li><span><a href="#Create-pandas-df-of-all-tables-and-columns-names" data-toc-modified-id="Create-pandas-df-of-all-tables-and-columns-names-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Create pandas df of all tables and columns names</a></span></li><li><span><a href="#Section4:-Assessment-1" data-toc-modified-id="Section4:-Assessment-1-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Section4: Assessment 1</a></span><ul class="toc-item"><li><span><a href="#qn1" data-toc-modified-id="qn1-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>qn1</a></span></li><li><span><a href="#qn2" data-toc-modified-id="qn2-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>qn2</a></span></li><li><span><a href="#qn3" data-toc-modified-id="qn3-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>qn3</a></span></li></ul></li></ul></div>

# %% [markdown]
# # SQL Introduction

# %% [markdown]
# ![](../images/sql_clauses.png)
# ![](../images/sql_mnemonic.png)

# %% [markdown]
# # Connect to the SQL

# %%
import numpy as np
import pandas as pd
import os
import yaml

with open( os.path.expanduser('~') + "/.postgres_conf.yml", 'r') as stream:
    try:
        yaml_dict = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

pw = yaml_dict['password']
port = yaml_dict['port']

# %load_ext sql
# %sql postgres://postgres:$pw@localhost:$port/dvdrental
# Out:
# 'Connected: postgres@dvdrental'

# %% [markdown]
# # Know your database

# %%
# %%sql
# SELECT TABLE_NAME
# FROM INFORMATION_SCHEMA.TABLES
# WHERE TABLE_TYPE = 'BASE TABLE'
# AND TABLE_CATALOG='dvdrental'
# and TABLE_NAME  not like 'pg_%'
# and TABLE_NAME  not like 'sql_%'
# -- order by table_name
# Out:
#  * postgres://postgres:***@localhost:5432/dvdrental
# 20 rows affected.
# [('actor',),
#  ('store',),
#  ('address',),
#  ('category',),
#  ('city',),
#  ('country',),
#  ('customer',),
#  ('film_actor',),
#  ('film_category',),
#  ('inventory',),
#  ('language',),
#  ('rental',),
#  ('staff',),
#  ('payment',),
#  ('film',),
#  ('employee',),
#  ('staffnew',),
#  ('df',),
#  ('sales2007q1',),
#  ('sales2007q2',)]

# %%
# %%sql
# select column_name, data_type, character_maximum_length
#     from INFORMATION_SCHEMA.COLUMNS
#     where table_name = 'customer';
# Out:
#  * postgres://postgres:***@localhost:5432/dvdrental
# 10 rows affected.
# [('customer_id', 'integer', None),
#  ('store_id', 'smallint', None),
#  ('first_name', 'character varying', 45),
#  ('last_name', 'character varying', 45),
#  ('email', 'character varying', 50),
#  ('address_id', 'smallint', None),
#  ('activebool', 'boolean', None),
#  ('create_date', 'date', None),
#  ('last_update', 'timestamp without time zone', None),
#  ('active', 'integer', None)]

# %%
# %%sql
# -- select * from staff limit 2; -- This gives error in jupyter notebook
# select * from actor limit 2;
# Out:
#  * postgres://postgres:***@localhost:5432/dvdrental
# 2 rows affected.
# [(1, 'Penelope', 'Guiness', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (2, 'Nick', 'Wahlberg', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))]

# %% [markdown]
# # Create pandas dataframes

# %%
staffs = pd.read_csv('../data/dvdrental/2187.dat', sep=r'\t',
                     header=None, engine='python')

cols = ['staff_id', 'first_name', 'last_name', 'address_id', 'email',
        'store_id', 'active', 'username', 'password', 'last_update',
        'picture']

staffs.columns = cols
staffs = staffs.head(2)
staffs['active'] = True
staffs.drop('picture',axis=1,inplace=True)
print(staffs.shape)
staffs.head()
# Out:
# (2, 10)
#    staff_id first_name last_name  address_id                         email  \
# 0         1       Mike   Hillyer           3  Mike.Hillyer@sakilastaff.com
# 1         2        Jon  Stephens           4  Jon.Stephens@sakilastaff.com
#
#    store_id  active username                                  password  \
# 0         1    True     Mike  8cb2237d0679ca88db6464eac60da96345513964
# 1         2    True      Jon  8cb2237d0679ca88db6464eac60da96345513964
#
#                  last_update
# 0  2006-05-16 16:13:11.79328
# 1  2006-05-16 16:13:11.79328

# %%
tables = ['staffs', 'category', 'film_category', 'country', 'actor',
          'language', 'inventory', 'payment', 'rental', 'city',
          'store', 'film', 'address', 'film_actor', 'customer']

staff = tables[0] # we do not use it, we use staffs dataframe. but keep name staffs.
category = tables[1]
film_category = tables[2]
country = tables[3]
actor = tables[4]
language = tables[5]
inventory = tables[6]
payment = tables[7]
rental = tables[8]
city = tables[9]
store = tables[10]
film = tables[11]
address = tables[12]
film_actor = tables[13]
customer = tables[14]

# %%
# first create separate sql tables so that we can convert them to pandas dataframes.
# staff = %sql select * from $staff;  # this fails
category = %sql select * from $category;
film_category = %sql select * from $film_category;
country = %sql select * from $country;
actor = %sql select * from $actor;
language = %sql select * from $language;
inventory = %sql select * from $inventory;
payment = %sql select * from $payment;
rental = %sql select * from $rental;
city = %sql select * from $city;
store = %sql select * from $store;
film = %sql select * from $film;
address = %sql select * from $address;
film_actor = %sql select * from $film_actor;
customer = %sql select * from $customer;
# Out:
#  * postgres://postgres:***@localhost:5432/dvdrental
# 16 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 1000 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 109 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 200 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 6 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 4581 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 14596 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 16044 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 600 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 2 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 1000 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 603 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 5462 rows affected.
#  * postgres://postgres:***@localhost:5432/dvdrental
# 599 rows affected.

# %%
category = category.DataFrame()
film_category = film_category.DataFrame()
country = country.DataFrame()
actor = actor.DataFrame()
language = language.DataFrame()
inventory = inventory.DataFrame()
payment = payment.DataFrame()
rental = rental.DataFrame()
city = city.DataFrame()
store = store.DataFrame()
film = film.DataFrame()
address = address.DataFrame()
film_actor = film_actor.DataFrame()
customer = customer.DataFrame()

# %% [markdown]
# # Make dataframes columns dtype good

# %%
df_tables = [staffs, category, film_category, country, actor,
            language, inventory, payment, rental, city,
            store, film, address, film_actor, customer]

# %%
def show_first_value_and_dtype(num):
    df_tables_dtypes = [df_tables[i].dtypes.to_frame()
                        for i in range(len(df_tables)) ]
    df_tables_first_value = [df_tables[i].head(1).T
                             for i in range(len(df_tables)) ]

    display(pd.concat([df_tables_first_value[num], df_tables_dtypes[num]],
                      axis=1, sort=True,ignore_index=True)
     .rename(columns={0: 'value', 1: 'dtype'})
     .style.apply(lambda x: ['background: lightblue' 
                             if x['dtype'] == 'object'
                             else ''
                             for _ in x],axis=1)
            .set_caption('Dataframe name: ' + tables[num])
    )

# %%
len(tables)
# Out:
# 15

# %%
show_first_value_and_dtype(0)
# Out:
# <style  type="text/css" >
#     #T_7a603c36_d691_11e9_9087_acde48001122row2_col0 {
#             background:  lightblue;
#         }    #T_7a603c36_d691_11e9_9087_acde48001122row2_col1 {
#             background:  lightblue;
#         }    #T_7a603c36_d691_11e9_9087_acde48001122row3_col0 {
#             background:  lightblue;
#         }    #T_7a603c36_d691_11e9_9087_acde48001122row3_col1 {
#             background:  lightblue;
#         }    #T_7a603c36_d691_11e9_9087_acde48001122row4_col0 {
#             background:  lightblue;
#         }    #T_7a603c36_d691_11e9_9087_acde48001122row4_col1 {
#             background:  lightblue;
#         }    #T_7a603c36_d691_11e9_9087_acde48001122row5_col0 {
#             background:  lightblue;
#         }    #T_7a603c36_d691_11e9_9087_acde48001122row5_col1 {
#             background:  lightblue;
#         }    #T_7a603c36_d691_11e9_9087_acde48001122row6_col0 {
#             background:  lightblue;
#         }    #T_7a603c36_d691_11e9_9087_acde48001122row6_col1 {
#             background:  lightblue;
#         }    #T_7a603c36_d691_11e9_9087_acde48001122row9_col0 {
#             background:  lightblue;
#         }    #T_7a603c36_d691_11e9_9087_acde48001122row9_col1 {
#             background:  lightblue;
#         }</style><table id="T_7a603c36_d691_11e9_9087_acde48001122" ><caption>Dataframe name: staffs</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >value</th>        <th class="col_heading level0 col1" >dtype</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a603c36_d691_11e9_9087_acde48001122level0_row0" class="row_heading level0 row0" >active</th>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row0_col0" class="data row0 col0" >True</td>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row0_col1" class="data row0 col1" >bool</td>
#             </tr>
#             <tr>
#                         <th id="T_7a603c36_d691_11e9_9087_acde48001122level0_row1" class="row_heading level0 row1" >address_id</th>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row1_col1" class="data row1 col1" >int64</td>
#             </tr>
#             <tr>
#                         <th id="T_7a603c36_d691_11e9_9087_acde48001122level0_row2" class="row_heading level0 row2" >email</th>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row2_col0" class="data row2 col0" >Mike.Hillyer@sakilastaff.com</td>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row2_col1" class="data row2 col1" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_7a603c36_d691_11e9_9087_acde48001122level0_row3" class="row_heading level0 row3" >first_name</th>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row3_col0" class="data row3 col0" >Mike</td>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row3_col1" class="data row3 col1" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_7a603c36_d691_11e9_9087_acde48001122level0_row4" class="row_heading level0 row4" >last_name</th>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row4_col0" class="data row4 col0" >Hillyer</td>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row4_col1" class="data row4 col1" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_7a603c36_d691_11e9_9087_acde48001122level0_row5" class="row_heading level0 row5" >last_update</th>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row5_col0" class="data row5 col0" >2006-05-16 16:13:11.79328</td>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row5_col1" class="data row5 col1" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_7a603c36_d691_11e9_9087_acde48001122level0_row6" class="row_heading level0 row6" >password</th>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row6_col0" class="data row6 col0" >8cb2237d0679ca88db6464eac60da96345513964</td>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row6_col1" class="data row6 col1" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_7a603c36_d691_11e9_9087_acde48001122level0_row7" class="row_heading level0 row7" >staff_id</th>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row7_col0" class="data row7 col0" >1</td>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row7_col1" class="data row7 col1" >int64</td>
#             </tr>
#             <tr>
#                         <th id="T_7a603c36_d691_11e9_9087_acde48001122level0_row8" class="row_heading level0 row8" >store_id</th>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row8_col0" class="data row8 col0" >1</td>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row8_col1" class="data row8 col1" >int64</td>
#             </tr>
#             <tr>
#                         <th id="T_7a603c36_d691_11e9_9087_acde48001122level0_row9" class="row_heading level0 row9" >username</th>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row9_col0" class="data row9 col0" >Mike</td>
#                         <td id="T_7a603c36_d691_11e9_9087_acde48001122row9_col1" class="data row9 col1" >object</td>
#             </tr>
#     </tbody></table>

# %%
staffs['last_update'] = pd.to_datetime(staffs['last_update'])

payment['amount'] = pd.to_numeric(payment['amount'], errors='coerce')

film['rental_rate'] = pd.to_numeric(film['rental_rate'], errors='coerce')
film['replacement_cost'] = pd.to_numeric(film['replacement_cost'], errors='coerce')

customer['create_date'] = pd.to_datetime(customer['create_date'])

# %% [markdown]
# # Create pandas df of all tables and columns names

# %%
df_tables = [staffs, category, film_category, country, actor,
            language, inventory, payment, rental, city,
            store, film, address, film_actor, customer]

all_columns = [df.columns.tolist() for df in df_tables]
df_tables_cols = pd.DataFrame(all_columns).T.fillna('')
df_tables_cols.columns = tables
df_tables_cols
# Out:
#          staffs     category film_category      country        actor  \
# 0      staff_id  category_id       film_id   country_id     actor_id
# 1    first_name         name   category_id      country   first_name
# 2     last_name  last_update   last_update  last_update    last_name
# 3    address_id                                          last_update
# 4         email
# 5      store_id
# 6        active
# 7      username
# 8      password
# 9   last_update
# 10
# 11
# 12
#
#        language     inventory       payment        rental         city  \
# 0   language_id  inventory_id    payment_id     rental_id      city_id
# 1          name       film_id   customer_id   rental_date         city
# 2   last_update      store_id      staff_id  inventory_id   country_id
# 3                 last_update     rental_id   customer_id  last_update
# 4                                    amount   return_date
# 5                              payment_date      staff_id
# 6                                             last_update
# 7
# 8
# 9
# 10
# 11
# 12
#
#                store              film      address   film_actor     customer
# 0           store_id           film_id   address_id     actor_id  customer_id
# 1   manager_staff_id             title      address      film_id     store_id
# 2         address_id       description     address2  last_update   first_name
# 3        last_update      release_year     district                 last_name
# 4                          language_id      city_id                     email
# 5                      rental_duration  postal_code                address_id
# 6                          rental_rate        phone                activebool
# 7                               length  last_update               create_date
# 8                     replacement_cost                            last_update
# 9                               rating                                 active
# 10                         last_update
# 11                    special_features
# 12                            fulltext

# %%
# find repeated column names
repeated_cols = (pd.Series([i for sub in all_columns for i in sub])
                 .value_counts()
                 .loc[lambda x: x>1]
                 .index.values.tolist()
                )
# create colors dict
cells = repeated_cols
colors = ['salmon', 'khaki','rosybrown','tomato',
          'olive', 'gray',  'mediumpurple',
          'orchid',  'plum','lavender', 'lightgreen',
          'lightsteelblue', 
          'lightblue','skyblue','orange','orangered'][:len(cells)]
cell_colors = dict(zip(cells,colors))

# colored dataframe
df_tables_cols.style.apply(lambda x: ["background: %s" % cell_colors[v] 
                          if  v in cell_colors.keys()
                          else "" for v in x], axis = 1)
# Out:
# <style  type="text/css" >
#     #T_7a721834_d691_11e9_9087_acde48001122row0_col0 {
#             background:  orchid;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row0_col1 {
#             background:  skyblue;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row0_col2 {
#             background:  rosybrown;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row0_col3 {
#             background:  lightsteelblue;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row0_col5 {
#             background:  orange;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row0_col6 {
#             background:  lightgreen;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row0_col8 {
#             background:  orangered;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row0_col9 {
#             background:  plum;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row0_col10 {
#             background:  khaki;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row0_col11 {
#             background:  rosybrown;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row0_col12 {
#             background:  tomato;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row0_col14 {
#             background:  gray;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row1_col0 {
#             background:  olive;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row1_col2 {
#             background:  skyblue;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row1_col4 {
#             background:  olive;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row1_col6 {
#             background:  rosybrown;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row1_col7 {
#             background:  gray;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row1_col13 {
#             background:  rosybrown;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row1_col14 {
#             background:  khaki;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col0 {
#             background:  mediumpurple;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col1 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col2 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col3 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col4 {
#             background:  mediumpurple;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col5 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col6 {
#             background:  khaki;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col7 {
#             background:  orchid;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col8 {
#             background:  lightgreen;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col9 {
#             background:  lightsteelblue;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col10 {
#             background:  tomato;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col13 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row2_col14 {
#             background:  olive;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row3_col0 {
#             background:  tomato;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row3_col4 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row3_col6 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row3_col7 {
#             background:  orangered;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row3_col8 {
#             background:  gray;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row3_col9 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row3_col10 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row3_col14 {
#             background:  mediumpurple;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row4_col0 {
#             background:  lavender;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row4_col11 {
#             background:  orange;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row4_col12 {
#             background:  plum;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row4_col14 {
#             background:  lavender;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row5_col0 {
#             background:  khaki;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row5_col8 {
#             background:  orchid;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row5_col14 {
#             background:  tomato;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row6_col0 {
#             background:  lightblue;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row6_col8 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row7_col12 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row8_col14 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row9_col0 {
#             background:  salmon;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row9_col14 {
#             background:  lightblue;
#         }    #T_7a721834_d691_11e9_9087_acde48001122row10_col11 {
#             background:  salmon;
#         }</style><table id="T_7a721834_d691_11e9_9087_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >staffs</th>        <th class="col_heading level0 col1" >category</th>        <th class="col_heading level0 col2" >film_category</th>        <th class="col_heading level0 col3" >country</th>        <th class="col_heading level0 col4" >actor</th>        <th class="col_heading level0 col5" >language</th>        <th class="col_heading level0 col6" >inventory</th>        <th class="col_heading level0 col7" >payment</th>        <th class="col_heading level0 col8" >rental</th>        <th class="col_heading level0 col9" >city</th>        <th class="col_heading level0 col10" >store</th>        <th class="col_heading level0 col11" >film</th>        <th class="col_heading level0 col12" >address</th>        <th class="col_heading level0 col13" >film_actor</th>        <th class="col_heading level0 col14" >customer</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a721834_d691_11e9_9087_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col0" class="data row0 col0" >staff_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col1" class="data row0 col1" >category_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col2" class="data row0 col2" >film_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col3" class="data row0 col3" >country_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col4" class="data row0 col4" >actor_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col5" class="data row0 col5" >language_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col6" class="data row0 col6" >inventory_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col7" class="data row0 col7" >payment_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col8" class="data row0 col8" >rental_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col9" class="data row0 col9" >city_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col10" class="data row0 col10" >store_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122row0_col11" class="data row0 col11" >film_id</td>
#                         <td id="T_7a721834_d691_11e9_9087_acde48001122ro

# %% [markdown]
# # Section4: Assessment 1
# ASSESSMENT TEST 1
#
# COMPLETE THE FOLLOWING TASKS!
#
# 1. Return the customer IDs of customers who have spent at least $110 with the staff member who has an ID of 2.
#
# The answer should be customers 187 and 148.
#
# 2. How many films begin with the letter J?
#
# The answer should be 20.
#
# 3. What customer has the highest customer ID number whose name starts with an 'E' and has an address ID lower than 500?
#
# The answer is Eddie Tomlin

# %% [markdown]
# ## qn1
# Return the customer IDs of customers who have spent at least $110 with the staff member who has an ID of 2.
# The answer should be customers 187 and 148.

# %%
df_tables_cols
# Out:
#          staffs     category film_category      country        actor  \
# 0      staff_id  category_id       film_id   country_id     actor_id
# 1    first_name         name   category_id      country   first_name
# 2     last_name  last_update   last_update  last_update    last_name
# 3    address_id                                          last_update
# 4         email
# 5      store_id
# 6        active
# 7      username
# 8      password
# 9   last_update
# 10
# 11
# 12
#
#        language     inventory       payment        rental         city  \
# 0   language_id  inventory_id    payment_id     rental_id      city_id
# 1          name       film_id   customer_id   rental_date         city
# 2   last_update      store_id      staff_id  inventory_id   country_id
# 3                 last_update     rental_id   customer_id  last_update
# 4                                    amount   return_date
# 5                              payment_date      staff_id
# 6                                             last_update
# 7
# 8
# 9
# 10
# 11
# 12
#
#                store              film      address   film_actor     customer
# 0           store_id           film_id   address_id     actor_id  customer_id
# 1   manager_staff_id             title      address      film_id     store_id
# 2         address_id       description     address2  last_update   first_name
# 3        last_update      release_year     district                 last_name
# 4                          language_id      city_id                     email
# 5                      rental_duration  postal_code                address_id
# 6                          rental_rate        phone                activebool
# 7                               length  last_update               create_date
# 8                     replacement_cost                            last_update
# 9                               rating                                 active
# 10                         last_update
# 11                    special_features
# 12                            fulltext

# %%
# %%sql
# select * from payment limit 2;
# Out:
#  * postgres://postgres:***@localhost:5432/dvdrental
# 2 rows affected.
# [(17503, 341, 2, 1520, Decimal('7.99'), datetime.datetime(2007, 2, 15, 22, 25, 46, 996577)),
#  (17504, 341, 1, 1778, Decimal('1.99'), datetime.datetime(2007, 2, 16, 17, 23, 14, 996577))]

# %%
# %%sql
# select customer_id, sum(amount)
# from payment
# where staff_id = 2
# group by customer_id
# having sum(amount) >= 110;
# Out:
#  * postgres://postgres:***@localhost:5432/dvdrental
# 2 rows affected.
# [(187, Decimal('110.81')), (148, Decimal('110.78'))]

# %%
payment.query('staff_id == 2')[['customer_id','amount']]\
.groupby('customer_id').sum().reset_index().query('amount >= 110')
# Out:
#      customer_id  amount
# 147          148  110.78
# 186          187  110.81

# %% [markdown]
# ## qn2
# How many films begin with the letter J?
# The answer should be 20.

# %%
# %%sql
# select * from film limit 2;
# Out:
#  * postgres://postgres:***@localhost:5432/dvdrental
# 2 rows affected.
# [(133, 'Chamber Italian', 'A Fateful Reflection of a Moose And a Husband who must Overcome a Monkey in Nigeria', 2006, 1, 7, Decimal('4.99'), 117, Decimal('14.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'chamber':1 'fate':4 'husband':11 'italian':2 'monkey':16 'moos':8 'must':13 'nigeria':18 'overcom':14 'reflect':5"),
#  (384, 'Grosse Wonderful', 'A Epic Drama of a Cat And a Explorer who must Redeem a Moose in Australia', 2006, 1, 5, Decimal('4.99'), 49, Decimal('19.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Behind the Scenes'], "'australia':18 'cat':8 'drama':5 'epic':4 'explor':11 'gross':1 'moos':16 'must':13 'redeem':14 'wonder':2")]

# %%
# %%sql
# select count(title) from film
# where title like 'J%';
# Out:
#  * postgres://postgres:***@localhost:5432/dvdrental
# 1 rows affected.
# [(20,)]

# %%
film.title.loc[film.title.str.startswith('J')].shape
# Out:
# (20,)

# %%
film.title.loc[film.title.str.startswith('J')]
# Out:
# 472          Jacket Frisco
# 473             Jade Bunch
# 474           Japanese Run
# 475             Jason Trap
# 476    Jawbreaker Brooklyn
# 477             Jaws Harry
# 478           Jedi Beneath
# 479        Jeepers Wedding
# 480         Jekyll Frogmen
# 481        Jeopardy Encino
# 482          Jericho Mulan
# 483          Jerk Paycheck
# 484           Jersey Sassy
# 485          Jet Neighbors
# 486       Jingle Sagebrush
# 487         Joon Northwest
# 488         Juggler Hardly
# 489          Jumanji Blade
# 490          Jumping Wrath
# 491          Jungle Closer
# Name: title, dtype: object

# %%
film.loc[film.title.str.startswith('J')][['title']]
# Out:
#                    title
# 472        Jacket Frisco
# 473           Jade Bunch
# 474         Japanese Run
# 475           Jason Trap
# 476  Jawbreaker Brooklyn
# 477           Jaws Harry
# 478         Jedi Beneath
# 479      Jeepers Wedding
# 480       Jekyll Frogmen
# 481      Jeopardy Encino
# 482        Jericho Mulan
# 483        Jerk Paycheck
# 484         Jersey Sassy
# 485        Jet Neighbors
# 486     Jingle Sagebrush
# 487       Joon Northwest
# 488       Juggler Hardly
# 489        Jumanji Blade
# 490        Jumping Wrath
# 491        Jungle Closer

# %%
film.title.filter(regex=r'472') # pandas series filter if for index filtering.
# Out:
# 472    Jacket Frisco
# Name: title, dtype: object

# %%
film.title.reset_index().set_index('title').filter(regex='^J.*',axis=0)
# Out:
#                      index
# title
# Jacket Frisco          472
# Jade Bunch             473
# Japanese Run           474
# Jason Trap             475
# Jawbreaker Brooklyn    476
# Jaws Harry             477
# Jedi Beneath           478
# Jeepers Wedding        479
# Jekyll Frogmen         480
# Jeopardy Encino        481
# Jericho Mulan          482
# Jerk Paycheck          483
# Jersey Sassy           484
# Jet Neighbors          485
# Jingle Sagebrush       486
# Joon Northwest         487
# Juggler Hardly         488
# Jumanji Blade          489
# Jumping Wrath          490
# Jungle Closer          491

# %% [markdown]
# ## qn3
# > What customer has the highest customer ID number whose name starts with an 'E' and has an address ID lower than 500?
#
# - The answer is Eddie Tomlin

# %%
df_tables_cols.style.apply(lambda x: ["background: salmon" if  
  (v == 'customer_id' or v == 'address_id') else "" for v in x], axis = 1)
# Out:
# <style  type="text/css" >
#     #T_7a967f62_d691_11e9_9087_acde48001122row0_col12 {
#             background:  salmon;
#         }    #T_7a967f62_d691_11e9_9087_acde48001122row0_col14 {
#             background:  salmon;
#         }    #T_7a967f62_d691_11e9_9087_acde48001122row1_col7 {
#             background:  salmon;
#         }    #T_7a967f62_d691_11e9_9087_acde48001122row2_col10 {
#             background:  salmon;
#         }    #T_7a967f62_d691_11e9_9087_acde48001122row3_col0 {
#             background:  salmon;
#         }    #T_7a967f62_d691_11e9_9087_acde48001122row3_col8 {
#             background:  salmon;
#         }    #T_7a967f62_d691_11e9_9087_acde48001122row5_col14 {
#             background:  salmon;
#         }</style><table id="T_7a967f62_d691_11e9_9087_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >staffs</th>        <th class="col_heading level0 col1" >category</th>        <th class="col_heading level0 col2" >film_category</th>        <th class="col_heading level0 col3" >country</th>        <th class="col_heading level0 col4" >actor</th>        <th class="col_heading level0 col5" >language</th>        <th class="col_heading level0 col6" >inventory</th>        <th class="col_heading level0 col7" >payment</th>        <th class="col_heading level0 col8" >rental</th>        <th class="col_heading level0 col9" >city</th>        <th class="col_heading level0 col10" >store</th>        <th class="col_heading level0 col11" >film</th>        <th class="col_heading level0 col12" >address</th>        <th class="col_heading level0 col13" >film_actor</th>        <th class="col_heading level0 col14" >customer</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a967f62_d691_11e9_9087_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col0" class="data row0 col0" >staff_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col1" class="data row0 col1" >category_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col2" class="data row0 col2" >film_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col3" class="data row0 col3" >country_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col4" class="data row0 col4" >actor_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col5" class="data row0 col5" >language_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col6" class="data row0 col6" >inventory_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col7" class="data row0 col7" >payment_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col8" class="data row0 col8" >rental_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col9" class="data row0 col9" >city_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col10" class="data row0 col10" >store_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col11" class="data row0 col11" >film_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col12" class="data row0 col12" >address_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col13" class="data row0 col13" >actor_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row0_col14" class="data row0 col14" >customer_id</td>
#             </tr>
#             <tr>
#                         <th id="T_7a967f62_d691_11e9_9087_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col0" class="data row1 col0" >first_name</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col1" class="data row1 col1" >name</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col2" class="data row1 col2" >category_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col3" class="data row1 col3" >country</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col4" class="data row1 col4" >first_name</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col5" class="data row1 col5" >name</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col6" class="data row1 col6" >film_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col7" class="data row1 col7" >customer_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col8" class="data row1 col8" >rental_date</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col9" class="data row1 col9" >city</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col10" class="data row1 col10" >manager_staff_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col11" class="data row1 col11" >title</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col12" class="data row1 col12" >address</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col13" class="data row1 col13" >film_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row1_col14" class="data row1 col14" >store_id</td>
#             </tr>
#             <tr>
#                         <th id="T_7a967f62_d691_11e9_9087_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col0" class="data row2 col0" >last_name</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col1" class="data row2 col1" >last_update</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col2" class="data row2 col2" >last_update</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col3" class="data row2 col3" >last_update</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col4" class="data row2 col4" >last_name</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col5" class="data row2 col5" >last_update</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col6" class="data row2 col6" >store_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col7" class="data row2 col7" >staff_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col8" class="data row2 col8" >inventory_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col9" class="data row2 col9" >country_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col10" class="data row2 col10" >address_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col11" class="data row2 col11" >description</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col12" class="data row2 col12" >address2</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col13" class="data row2 col13" >last_update</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row2_col14" class="data row2 col14" >first_name</td>
#             </tr>
#             <tr>
#                         <th id="T_7a967f62_d691_11e9_9087_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row3_col0" class="data row3 col0" >address_id</td>
#                         <td id="T_7a967f62_d691_11e9_9087_acde48001122row3_col1" class="data row3 col1" ></td>

# %%
# %%sql
# select * from customer limit 2;
# Out:
#  * postgres://postgres:***@localhost:5432/dvdrental
# 2 rows affected.
# [(524, 1, 'Jared', 'Ely', 'jared.ely@sakilacustomer.org', 530, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (1, 1, 'Mary', 'Smith', 'mary.smith@sakilacustomer.org', 5, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)]

# %%
# %%sql
# select customer_id, first_name, last_name, address_id
# from customer
# where first_name like 'E%' and address_id < 500
# order by customer_id desc
# limit 1;
# Out:
#  * postgres://postgres:***@localhost:5432/dvdrental
# 1 rows affected.
# [(434, 'Eddie', 'Tomlin', 439)]

# %%
customer[customer.first_name.str.startswith('E')]\
.query('address_id < 500')\
.nlargest(1, 'customer_id')\
.loc[:, ['customer_id','first_name','last_name','address_id']]
# Out:
#      customer_id first_name last_name  address_id
# 434          434      Eddie    Tomlin         439

# %%
customer[customer.first_name.str.startswith('E')]\
.loc[lambda x: x['address_id'] < 500]\
.nlargest(1, 'customer_id')\
.loc[:, ['customer_id','first_name','last_name','address_id']]
# Out:
#      customer_id first_name last_name  address_id
# 434          434      Eddie    Tomlin         439
